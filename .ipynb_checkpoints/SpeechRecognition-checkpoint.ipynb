# %% [markdown]
# **Install and Import Dependenies**

# %%
# !pip install matplotlib tensorflow==2.4.1 tensorflow-io tensorflow-gpu==2.4.1
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting matplotlib
#   Using cached matplotlib-3.7.0-cp39-cp39-macosx_11_0_arm64.whl (7.3 MB)
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow==2.4.1

# %% [markdown]
# Tensorflow-io is install for audio processing

# %%
from matplotlib import pyplot as plt
import tensorflow_io as tfio
import os
import tensorflow as tf 
import csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 from matplotlib import pyplot as plt
#       2 import tensorflow_io as tfio
#       3 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# How paths are defined
# <br>CB -> Cappuchin Bird
# <br>NCB -> Non Cappuchin Bird
# <br> Change the file path according to user need.

# %%
positive_label_path = '/content/Data/PCB'
negative_label_path = '/content/Data/PNCB'

# %%
File_CB = os.path.join(positive_label_path, 'XC114131-1.wav')
File_NCB = os.path.join(negative_label_path,'Crickets-chirping-0.wav')

# %% [markdown]
# Processing Audio to convert it into 16hz single-channel

# %%
def wave_processing(filepath):
  content = tf.io.read_file(filepath)
  wave, sr = tf.audio.decode_wav(content, desired_channels=1)
  wave = tf.squeeze(wave, axis=-1)
  sr = tf.cast(sr, dtype=tf.int64)
  wave = tfio.audio.resample(wave, rate_in=sr, rate_out=16000)
  return wave

# %% [markdown]
# Sample waves from dataset provided

# %%
sample1 = wave_processing(File_CB)
sample2 = wave_processing(File_NCB)

# %%
print(sample1)
# Out:
# tf.Tensor(
# [-2.38103937e-08 -1.19024826e-08 -6.48144649e-08 ... -5.84699772e-03
#   6.84118923e-03 -6.73171133e-03], shape=(48000,), dtype=float32)

# %%
plt.figure(1)
plt.plot(sample1)
plt.plot(sample2)
plt.show()

# %% [markdown]
# **Make Sound dataset**<br>
# We will define filepaths for positive and negative data

# %%
positive_files = tf.data.Dataset.list_files(positive_label_path+'/*.wav')
negative_files = tf.data.Dataset.list_files(negative_label_path+'/*.wav')

# %%
positive_files.as_numpy_iterator().next()
# Out:
# b'/content/Data/PCB/XC40355-0.wav'

# %% [markdown]
# Provide positive and negative labels for all the dataset files and combine the samples

# %%
positive_label = tf.data.Dataset.zip((positive_files, tf.data.Dataset.from_tensor_slices(tf.ones(len(positive_files)))))
negative_label = tf.data.Dataset.zip((negative_files, tf.data.Dataset.from_tensor_slices(tf.ones(len(negative_files)))))
dataset = positive_label.concatenate(negative_label)

# %%
dataset
# Out:
# <ConcatenateDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %% [markdown]
# Calculate how long is the average Capuchin bird call

# %%
call_length = []
for ele in os.listdir(positive_label_path):
  wave = wave_processing(os.path.join(positive_label_path, ele))
  call_length.append(len(wave))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f7752a51430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f7756620430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
len(call_length)
# Out:
# 217

# %% [markdown]
# Determine Max, Min, and Mean length of call

# %%
print('Max Length: ', tf.math.reduce_max(call_length))
print('Min Length: ', tf.math.reduce_min(call_length))
print('Mean Length: ', tf.math.reduce_mean(call_length))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9cf9257bbb0e> in <module>
# ----> 1 print('Max Length: ', tf.math.reduce_max(call_length))
#       2 print('Min Length: ', tf.math.reduce_min(call_length))
#       3 print('Mean Length: ', tf.math.reduce_mean(call_length))
#
# NameError: name 'call_length' is not defined

# %% [markdown]
# Function to convert the waveform to Spectrogram

# %%
def wave_to_spectro(path, label):
  waveform = wave_processing(path)
  waveform = waveform[:48000]
  padding_with_zero = tf.zeros([48000] - tf.shape(waveform), dtype=tf.float32)
  waveform = tf.concat([padding_with_zero, waveform], 0)
  spectro = tf.signal.stft(waveform, frame_length=320, frame_step=32)
  spectro = tf.abs(spectro)
  spectro = tf.expand_dims(spectro, axis=2)
  return spectro, label

# %%
path, label = positive_label.shuffle(buffer_size=1000).as_numpy_iterator().next()

# %%
print(path)
# Out:
# b'/content/Data/PCB/XC227471-6.wav'

# %%
spectro, label = wave_to_spectro(path, label)

# %%
print(spectro.shape)
# Out:
# (1491, 257, 1)

# %%
plt.figure(figsize=(40,20))
plt.imshow(tf.transpose(spectro)[0])
plt.show()

# %% [markdown]
# Build a Data pipeline for tensorflow

# %%
dataset.as_numpy_iterator().next()
# Out:
# (b'/content/Data/PCB/XC216012-15.wav', 1.0)

# %%
dataset = dataset.map(wave_to_spectro)
dataset = dataset.cache()
dataset = dataset.shuffle(buffer_size=1000)
dataset = dataset.batch(16)
dataset = dataset.prefetch(8)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.

# %% [markdown]
# Create a split of training and test data

# %%
train_data_size = round(len(dataset) * 0.7)

# %%
test_data_size = len(dataset) - train_data_size

# %%
training_data = dataset.take(train_data_size)
testing_data = dataset.skip(train_data_size).take(test_data_size)

# %% [markdown]
# Add Tensorflow dependencies

# %%
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# %% [markdown]
# Create Model

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(16, (3,3), activation='relu', input_shape=(1491, 257, 1)))
cnn_model.add(Conv2D(16, (3,3), activation='relu'))
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dense(1, activation='sigmoid'))

# %%
cnn_model.compile('Adam', loss='BinaryCrossentropy', metrics=[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1489, 255, 16)     160
#
#  conv2d_1 (Conv2D)           (None, 1487, 253, 16)     2320
#
#  flatten (Flatten)           (None, 6019376)           0
#
#  dense (Dense)               (None, 128)               770480256
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 770,482,865
# Trainable params: 770,482,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn_model.fit(training_data, epochs=4, validation_data=testing_data)
# Out:
# Epoch 1/4

# %%
plt.title('Loss Graph')
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'r')
plt.show()

# %%
plt.title('Precision Graph')
plt.plot(history.history['precision'], 'b')
plt.plot(history.history['val_precision'], 'r')
plt.show()

# %%
plt.title('Recall')
plt.plot(history.history['recall'], 'r')
plt.plot(history.history['val_recall'], 'b')
plt.show()

# %% [markdown]
# Do a single prediction

# %%
X_test, y_test = testing_data.as_numpy_iterator().next()

# %%
yhat = cnn_model.predict(X_test)

# %%
yhat = [1 if prediction > 0.45 else 0 for prediction in yhat]
